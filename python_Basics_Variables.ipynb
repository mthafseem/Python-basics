# %%
print('hello') #to print the value
# Out:
# hello

# %% [markdown]
# #SECTION 1

# %% [markdown]
# ##sub section

# %%
location, wheather, famous_for,state,registration = 'kozhikode','cloudy','food','kerala','kL11'
location ,wheather,famous_for,state,registration
# Out:
# ('kozhikode', 'cloudy', 'food', 'kerala', 'kL11')

# %% [markdown]
# #Rules for naming
# 1. must start with a letter or underscore`_`
# 2. cannot start with anumber
# 3. can contain letters,digits,and underscores
# 3. case_sensitive `Name not equal to name`
# 4. Should not use python keywords (`if`,`for`,`class`,etc.)

# %%
x = 10
name ='Alice'
_price = 99.99
is_active =True
print(x,name,_price,is_active)
# Out:
# 10 Alice 99.99 True

# %%
name = 'Thafseem'
print(name)
print('Muhammed')
print('My name is:',name)
a = 10
print(a)
b = 2.343434543
# Out:
# Thafseem
# Muhammed
# My name is: Thafseem
# 10

# %%
print(type(name),type(a),type(b),type(is_active))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
hospital_name, location, hospital_type, specialty, state, registration, beds, doctors, nurses, emergency, ambulance, pharmacy, icu, established, rating = 'Aster MIMS', 'Kozhikode', 'Multi Speciality', 'Cardiology', 'Kerala', 'HSP12345', 750, 250, 600, True, True, True, True, 2002, 4.8
print('the location of current hospital is:',location)
